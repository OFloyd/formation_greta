# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import time
# import re
import random
# import pickle
import datasets as dst

# %%
import sklearn as skl
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, mean_absolute_error

# %%
df = dst.getDataset("2023_03_21")

# %%
df
# Out:
#           station_id  num_bikes_available  num_bikes_available_mech  \
# 0          213688169                    3                       1.0
# 1          213688169                    3                       1.0
# 2          213688169                    3                       1.0
# 3          213688169                    3                       1.0
# 4          213688169                    3                       1.0
# ...              ...                  ...                       ...
# 1030232  17451195211                    0                       0.0
# 1030233  17451195211                    0                       0.0
# 1030234  17451195211                    0                       0.0
# 1030235  17451195211                    0                       0.0
# 1030236  17451195211                    0                       0.0
#
#          num_bikes_available_elec  num_docks_available  is_installed  \
# 0                             2.0                   31             1
# 1                             2.0                   31             1
# 2                             2.0                   31             1
# 3                             2.0                   31             1
# 4                             2.0                   31             1
# ...                           ...                  ...           ...
# 1030232                       0.0                    0             0
# 1030233                       0.0                    0             0
# 1030234                       0.0                    0             0
# 1030235                       0.0                    0             0
# 1030236                       0.0                    0             0
#
#          is_returning  is_renting  last_reported                time  weekday  \
# 0                   1           1     1679351605 2023-03-21 00:00:02        1
# 1                   1           1     1679351605 2023-03-21 00:03:02        1
# 2                   1           1     1679351605 2023-03-21 00:05:02        1
# 3                   1           1     1679351605 2023-03-21 00:07:02        1
# 4                   1           1     1679351605 2023-03-21 00:09:02        1
# ...               ...         ...            ...                 ...      ...
# 1030232             0           0     1671722759 2023-03-21 23:50:46        1
# 1030233             0           0     1671722759 2023-03-21 23:52:46        1
# 1030234             0           0     1671722759 2023-03-21 23:54:46        1
# 1030235             0           0     1671722759 2023-03-21 23:56:46        1
# 1030236             0           0     1671722759 2023-03-21 23:58:46        1
#
#              hour                                   name        lat       lon  \
# 0        00:00:02          Benjamin Godard - Victor Hugo  48.865983  2.275725
# 1        00:03:02          Benjamin Godard - Victor Hugo  48.865983  2.275725
# 2        00:05:02          Benjamin Godard - Victor Hugo  48.865983  2.275725
# 3        00:07:02          Benjamin Godard - Victor Hugo  48.865983  2.275725
# 4        00:09:02          Benjamin Godard - Victor Hugo  48.865983  2.275725
# ...           ...                                    ...        ...       ...
# 1030232  23:50:46  Jean Bouin - Gouverneur Général Eboué  48.824793  2.265190
# 1030233  23:52:46  Jean Bouin - Gouverneur Général Eboué  48.824793  2.265190
# 1030234  23:54:46  Jean Bouin - Gouverneur Général Eboué  48.824793  2.265190
# 1030235  23:56:46  Jean Bouin - Gouverneur Général Eboué  48.824793  2.265190
# 1030236  23:58:46  Jean Bouin - Gouverneur Général Eboué  48.824793  2.265190
#
#          capacity  occupation_prct  occupation_class
# 0              35         8.571429                 1
# 1              35         8.571429                 1
# 2              35         8.571429                 1
# 3              35         8.571429                 1
# 4              35         8.571429                 1
# ...           ...              ...               ...
# 1030232         0              NaN                 0
# 1030233         0              NaN                 0
# 1030234         0              NaN                 0
# 1030235         0              NaN                 0
# 1030236         0              NaN                 0
#
# [1030237 rows x 18 columns]

# %%
df["occupation_prct"].isna().value_counts()
# Out:
# False    1018812
# True       11425
# Name: occupation_prct, dtype: int64

# %%
df.dropna()
# Out:
#          station_id  num_bikes_available  num_bikes_available_mech  \
# 0         213688169                    3                       1.0
# 1         213688169                    3                       1.0
# 2         213688169                    3                       1.0
# 3         213688169                    3                       1.0
# 4         213688169                    3                       1.0
# ...             ...                  ...                       ...
# 1029427   315022587                    3                       2.0
# 1029428   315022587                    3                       2.0
# 1029429   315022587                    3                       2.0
# 1029430   315022587                    3                       2.0
# 1029431   315022587                    3                       2.0
#
#          num_bikes_available_elec  num_docks_available  is_installed  \
# 0                             2.0                   31             1
# 1                             2.0                   31             1
# 2                             2.0                   31             1
# 3                             2.0                   31             1
# 4                             2.0                   31             1
# ...                           ...                  ...           ...
# 1029427                       1.0                   60             1
# 1029428                       1.0                   60             1
# 1029429                       1.0                   60             1
# 1029430                       1.0                   60             1
# 1029431                       1.0                   60             1
#
#          is_returning  is_renting  last_reported                time  weekday  \
# 0                   1           1     1679351605 2023-03-21 00:00:02        1
# 1                   1           1     1679351605 2023-03-21 00:03:02        1
# 2                   1           1     1679351605 2023-03-21 00:05:02        1
# 3                   1           1     1679351605 2023-03-21 00:07:02        1
# 4                   1           1     1679351605 2023-03-21 00:09:02        1
# ...               ...         ...            ...                 ...      ...
# 1029427             1           1     1679438055 2023-03-21 23:50:46        1
# 1029428             1           1     1679438055 2023-03-21 23:52:46        1
# 1029429             1           1     1679438055 2023-03-21 23:54:46        1
# 1029430             1           1     1679438055 2023-03-21 23:56:46        1
# 1029431             1           1     1679438055 2023-03-21 23:58:46        1
#
#              hour                                 name        lat       lon  \
# 0        00:00:02        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 1        00:03:02        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 2        00:05:02        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 3        00:07:02        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 4        00:09:02        Benjamin Godard - Victor Hugo  48.865983  2.275725
# ...           ...                                  ...        ...       ...
# 1029427  23:50:46  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1029428  23:52:46  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1029429  23:54:46  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1029430  23:56:46  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1029431  23:58:46  Malesherbes - Place de la Madeleine  48.870406  2.323244
#
#          capacity  occupation_prct  occupation_class
# 0              35         8.571429                 1
# 1              35         8.571429                 1
# 2              35         8.571429                 1
# 3              35         8.571429                 1
# 4              35         8.571429                 1
# ...           ...              ...               ...
# 1029427        67         4.477612                 0
# 1029428        67         4.477612                 0
# 1029429        67         4.477612                 0
# 1029430        67         4.477612                 0
# 1029431        67         4.477612                 0
#
# [1010178 rows x 18 columns]

# %%
df[(df["is_installed"] == 1) & (df["capacity"] == 0)]
# Out:
#         station_id  num_bikes_available  num_bikes_available_mech  \
# 141600   129093478                    0                       0.0
# 141601   129093478                    0                       0.0
# 141602   129093478                    0                       0.0
# 141603   129093478                    0                       0.0
# 141604   129093478                    0                       0.0
# ...            ...                  ...                       ...
# 780919  1064008882                    0                       0.0
# 780920  1064008882                    0                       0.0
# 780921  1064008882                    0                       0.0
# 780922  1064008882                    0                       0.0
# 780923  1064008882                    0                       0.0
#
#         num_bikes_available_elec  num_docks_available  is_installed  \
# 141600                       0.0                    0             1
# 141601                       0.0                    0             1
# 141602                       0.0                    0             1
# 141603                       0.0                    0             1
# 141604                       0.0                    0             1
# ...                          ...                  ...           ...
# 780919                       0.0                    0             1
# 780920                       0.0                    0             1
# 780921                       0.0                    0             1
# 780922                       0.0                    0             1
# 780923                       0.0                    0             1
#
#         is_returning  is_renting  last_reported                time  weekday  \
# 141600             0           0     1676589623 2023-03-21 00:00:02        1
# 141601             0           0     1676589623 2023-03-21 00:03:02        1
# 141602             0           0     1676589623 2023-03-21 00:05:02        1
# 141603             0           0     1676589623 2023-03-21 00:07:02        1
# 141604             0           0     1676589623 2023-03-21 00:09:02        1
# ...              ...         ...            ...                 ...      ...
# 780919             0           0     1553093196 2023-03-21 23:50:46        1
# 780920             0           0     1553093196 2023-03-21 23:52:46        1
# 780921             0           0     1553093196 2023-03-21 23:54:46        1
# 780922             0           0     1553093196 2023-03-21 23:56:46        1
# 780923             0           0     1553093196 2023-03-21 23:58:46        1
#
#             hour                             name        lat       lon  \
# 141600  00:00:02  Place de la Porte de Champerret  48.885617  2.290781
# 141601  00:03:02  Place de la Porte de Champerret  48.885617  2.290781
# 141602  00:05:02  Place de la Porte de Champerret  48.885617  2.290781
# 141603  00:07:02  Place de la Porte de Champerret  48.885617  2.290781
# 141604  00:09:02  Place de la Porte de Champerret  48.885617  2.290781
# ...          ...                              ...        ...       ...
# 780919  23:50:46                  Poulet - Barbès  48.887148  2.349064
# 780920  23:52:46                  Poulet - Barbès  48.887148  2.349064
# 780921  23:54:46                  Poulet - Barbès  48.887148  2.349064
# 780922  23:56:46                  Poulet - Barbès  48.887148  2.349064
# 780923  23:58:46                  Poulet - Barbès  48.887148  2.349064
#
#         capacity  occupation_prct  occupation_class
# 141600         0              NaN                 0
# 141601         0              NaN                 0
# 141602         0              NaN                 0
# 141603         0              NaN                 0
# 141604         0              NaN                 0
# ...          ...              ...               ...
# 780919         0              NaN                 0
# 780920         0              NaN                 0
# 780921         0              NaN                 0
# 780922         0              NaN                 0
# 780923         0              NaN                 0
#
# [5664 rows x 18 columns]

# %%
df[df["capacity"] == 0].loc[::, ["station_id", "name", "is_installed", "is_returning", "is_renting"]].describe()
# Out:
#          station_id  is_installed  is_returning  is_renting
# count  1.142500e+04  11425.000000       11425.0     11425.0
# mean   8.805063e+09      0.495755           0.0         0.0
# std    8.419683e+09      0.500004           0.0         0.0
# min    7.619911e+07      0.000000           0.0         0.0
# 25%    2.370410e+08      0.000000           0.0         0.0
# 50%    1.637927e+10      0.000000           0.0         0.0
# 75%    1.727890e+10      1.000000           0.0         0.0
# max    1.745120e+10      1.000000           0.0         0.0

# %%
df[df["capacity"] == 0].loc[::, ["station_id", "name", "is_installed", "is_returning", "is_renting"]].value_counts()
# Out:
# station_id   name                                   is_installed  is_returning  is_renting
# 76199110     Université Paris Dauphine              1             0             0             708
# 16379269732  Président Roosevelt - Rouget de Lisle  0             0             0             708
# 17364714962  Marseillaise - Grenade                 0             0             0             708
# 17364417797  Decrès - Alésia                        0             0             0             708
# 17278902806  Rouget de L'isle - Watteau             0             0             0             708
# 17225742003  Louis Armand - Bernard Palissy         0             0             0             708
# 17174675707  Saint Pères - Saint Germain            0             0             0             708
# 100905057    Londres - Amsterdam                    1             0             0             708
# 16898865154  Stéphanie Bouvard - Gambetta           0             0             0             708
# 1064008882   Poulet - Barbès                        1             0             0             708
# 402212574    Charles de Gaulle - Graviers           1             0             0             708
# 335989765    Rond-Point de la Chapelle              1             0             0             708
# 237041013    Saint-Jacques - Soufflot               1             0             0             708
# 213691542    Porte Maillot - Pereire                1             0             0             708
# 129093478    Place de la Porte de Champerret        1             0             0             708
# 17450286381  Stalingrad - Barbara                   0             0             0             367
# 17451132826  Epi d'Or - Chevilly                    0             0             0             219
# 17451195211  Jean Bouin - Gouverneur Général Eboué  0             0             0             219
# dtype: int64

# %%
df2 = dst.getDataset("2023_03_20")

# %%
df = pd.concat([df, df2])

# %%
df[df["capacity"] == 0].loc[::, ["station_id", "name", "is_installed", "is_returning", "is_renting"]].value_counts()
# Out:
# station_id   name                                   is_installed  is_returning  is_renting
# 76199110     Université Paris Dauphine              1             0             0             1423
# 16379269732  Président Roosevelt - Rouget de Lisle  0             0             0             1423
# 17364714962  Marseillaise - Grenade                 0             0             0             1423
# 17364417797  Decrès - Alésia                        0             0             0             1423
# 17278902806  Rouget de L'isle - Watteau             0             0             0             1423
# 17225742003  Louis Armand - Bernard Palissy         0             0             0             1423
# 17174675707  Saint Pères - Saint Germain            0             0             0             1423
# 100905057    Londres - Amsterdam                    1             0             0             1423
# 16898865154  Stéphanie Bouvard - Gambetta           0             0             0             1423
# 1064008882   Poulet - Barbès                        1             0             0             1423
# 402212574    Charles de Gaulle - Graviers           1             0             0             1423
# 335989765    Rond-Point de la Chapelle              1             0             0             1423
# 237041013    Saint-Jacques - Soufflot               1             0             0             1423
# 213691542    Porte Maillot - Pereire                1             0             0             1423
# 129093478    Place de la Porte de Champerret        1             0             0             1423
# 17450286381  Stalingrad - Barbara                   0             0             0              367
# 17451132826  Epi d'Or - Chevilly                    0             0             0              219
# 17451195211  Jean Bouin - Gouverneur Général Eboué  0             0             0              219
# dtype: int64

# %%
df1 = dst.getDataset("2023_03_18")
df2 = dst.getDataset("2023_03_19")
df3 = dst.getDataset("2023_03_20")
df4 = dst.getDataset("2023_03_21")

df1 = df1[df1["station_id"] == 1109534105]
df2 = df2[df2["station_id"] == 1109534105]
df3 = df3[df3["station_id"] == 1109534105]
df4 = df4[df4["station_id"] == 1109534105]

df = pd.concat([df1.iloc[0::1],df2.iloc[0::1],df3.iloc[0::1],df4.iloc[0::1]])
df = df.dropna(subset = ["station_id", "lat", "lon", "seconds_since_midnight", "occupation_prct", "occupation_class"])

# %%
# feat=['station_id', 'capacity', 'seconds_since_midnight']
feat = ["lat", "lon", "seconds_since_midnight"]
target = ["occupation_class"]

x = df[feat]
y = df[target]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(x_train, y_train.values.ravel())
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, random_state=0)

# %%
y_pred = clf.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5475638051044084

# %%
print(feat)
clf.feature_importances_
# Out:
# ['lat', 'lon', 'seconds_since_midnight']
# array([0., 0., 1.])

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, cmap="Blues")
plt.xlabel('Prédictions')
plt.ylabel('Valeurs réelles')
plt.show()
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.19      0.25        58
#            1       0.63      0.65      0.64       117
#            2       0.54      0.53      0.54        92
#            3       0.44      0.56      0.49        77
#            4       0.61      0.66      0.63        87
#
#     accuracy                           0.55       431
#    macro avg       0.52      0.52      0.51       431
# weighted avg       0.54      0.55      0.54       431

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2152 entries, 495391 to 493349
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   station_id                2152 non-null   int64
#  1   num_bikes_available       2152 non-null   int64
#  2   num_bikes_available_mech  2138 non-null   float64
#  3   num_bikes_available_elec  2138 non-null   float64
#  4   num_docks_available       2152 non-null   int64
#  5   is_installed              2152 non-null   int64
#  6   is_returning              2152 non-null   int64
#  7   is_renting                2152 non-null   int64
#  8   last_reported             2152 non-null   int64
#  9   time                      2152 non-null   datetime64[ns]
#  10  weekday                   2152 non-null   int64
#  11  hour                      2152 non-null   object
#  12  name                      2152 non-null   object
#  13  lat                       2152 non-null   float64
#  14  lon                       2152 non-null   float64
#  15  capacity                  2152 non-null   int64
#  16  occupation_prct           2152 non-null   float64
#  17  occupation_class          2152 non-null   int64
#  18  seconds_since_midnight    2152 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(10), object(2)
# memory usage: 336.2+ KB

# %%
df[df["station_id"] == 13373801574]
# Out:
# Empty DataFrame
# Columns: [station_id, num_bikes_available, num_bikes_available_mech, num_bikes_available_elec, num_docks_available, is_installed, is_returning, is_renting, last_reported, time, weekday, hour, name, lat, lon, capacity, occupation_prct, occupation_class, seconds_since_midnight]
# Index: []

# %%
dftest = dst.getDataset("2023_03_21")

dftest[dftest["station_id"] == 100863462]
# Out:
#         station_id  num_bikes_available  num_bikes_available_mech  \
# 981996   100863462                    1                       1.0
# 981997   100863462                    1                       1.0
# 981998   100863462                    1                       1.0
# 981999   100863462                    1                       1.0
# 982000   100863462                    2                       1.0
# ...            ...                  ...                       ...
# 982699   100863462                    1                       1.0
# 982700   100863462                    1                       1.0
# 982701   100863462                    1                       1.0
# 982702   100863462                    1                       1.0
# 982703   100863462                    1                       1.0
#
#         num_bikes_available_elec  num_docks_available  is_installed  \
# 981996                       0.0                   60             1
# 981997                       0.0                   60             1
# 981998                       0.0                   60             1
# 981999                       0.0                   60             1
# 982000                       1.0                   59             1
# ...                          ...                  ...           ...
# 982699                       0.0                   58             1
# 982700                       0.0                   58             1
# 982701                       0.0                   58             1
# 982702                       0.0                   58             1
# 982703                       0.0                   58             1
#
#         is_returning  is_renting  last_reported                time  weekday  \
# 981996             1           1     1679351592 2023-03-21 00:00:02        1
# 981997             1           1     1679351592 2023-03-21 00:03:02        1
# 981998             1           1     1679351592 2023-03-21 00:05:02        1
# 981999             1           1     1679351592 2023-03-21 00:07:02        1
# 982000             1           1     1679351592 2023-03-21 00:09:02        1
# ...              ...         ...            ...                 ...      ...
# 982699             1           1     1679438002 2023-03-21 23:50:46        1
# 982700             1           1     1679438002 2023-03-21 23:52:46        1
# 982701             1           1     1679438002 2023-03-21 23:54:46        1
# 982702             1           1     1679438002 2023-03-21 23:56:46        1
# 982703             1           1     1679438002 2023-03-21 23:58:46        1
#
#             hour           name        lat      lon  capacity  \
# 981996  00:00:02  Musée d'Orsay  48.859726  2.32586        65
# 981997  00:03:02  Musée d'Orsay  48.859726  2.32586        65
# 981998  00:05:02  Musée d'Orsay  48.859726  2.32586        65
# 981999  00:07:02  Musée d'Orsay  48.859726  2.32586        65
# 982000  00:09:02  Musée d'Orsay  48.859726  2.32586        65
# ...          ...            ...        ...      ...       ...
# 982699  23:50:46  Musée d'Orsay  48.859726  2.32586        65
# 982700  23:52:46  Musée d'Orsay  48.859726  2.32586        65
# 982701  23:54:46  Musée d'Orsay  48.859726  2.32586        65
# 982702  23:56:46  Musée d'Orsay  48.859726  2.32586        65
# 982703  23:58:46  Musée d'Orsay  48.859726  2.32586        65
#
#         occupation_prct  occupation_class
# 981996         1.538462                 0
# 981997         1.538462                 0
# 981998         1.538462                 0
# 981999         1.538462                 0
# 982000         3.076923                 0
# ...                 ...               ...
# 982699         1.538462                 0
# 982700         1.538462                 0
# 982701         1.538462                 0
# 982702         1.538462                 0
# 982703         1.538462                 0
#
# [708 rows x 18 columns]

# %%
dftest = dst.getDataset("2023_03_20")

dftest
# Out:
#          station_id  num_bikes_available  num_bikes_available_mech  \
# 0         213688169                    6                       2.0
# 1         213688169                    6                       2.0
# 2         213688169                    6                       2.0
# 3         213688169                    6                       2.0
# 4         213688169                    5                       2.0
# ...             ...                  ...                       ...
# 1039605   315022587                    1                       0.0
# 1039606   315022587                    1                       0.0
# 1039607   315022587                    1                       0.0
# 1039608   315022587                    1                       0.0
# 1039609   315022587                    1                       0.0
#
#          num_bikes_available_elec  num_docks_available  is_installed  \
# 0                             4.0                   29             1
# 1                             4.0                   29             1
# 2                             4.0                   29             1
# 3                             4.0                   29             1
# 4                             3.0                   30             1
# ...                           ...                  ...           ...
# 1039605                       1.0                   63             1
# 1039606                       1.0                   63             1
# 1039607                       1.0                   63             1
# 1039608                       1.0                   63             1
# 1039609                       1.0                   63             1
#
#          is_returning  is_renting  last_reported                time  weekday  \
# 0                   1           1     1679264946 2023-03-20 00:00:18        0
# 1                   1           1     1679264946 2023-03-20 00:02:17        0
# 2                   1           1     1679264946 2023-03-20 00:04:18        0
# 3                   1           1     1679264946 2023-03-20 00:06:17        0
# 4                   1           1     1679264946 2023-03-20 00:08:18        0
# ...               ...         ...            ...                 ...      ...
# 1039605             1           1     1679351341 2023-03-20 23:49:01        0
# 1039606             1           1     1679351341 2023-03-20 23:52:01        0
# 1039607             1           1     1679351341 2023-03-20 23:54:01        0
# 1039608             1           1     1679351341 2023-03-20 23:56:01        0
# 1039609             1           1     1679351341 2023-03-20 23:58:01        0
#
#              hour                                 name        lat       lon  \
# 0        00:00:18        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 1        00:02:17        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 2        00:04:18        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 3        00:06:17        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 4        00:08:18        Benjamin Godard - Victor Hugo  48.865983  2.275725
# ...           ...                                  ...        ...       ...
# 1039605  23:49:01  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1039606  23:52:01  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1039607  23:54:01  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1039608  23:56:01  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1039609  23:58:01  Malesherbes - Place de la Madeleine  48.870406  2.323244
#
#          capacity  occupation_prct  occupation_class  seconds_since_midnight
# 0              35        17.142857                 1                      18
# 1              35        17.142857                 1                     137
# 2              35        17.142857                 1                     258
# 3              35        17.142857                 1                     377
# 4              35        14.285714                 1                     498
# ...           ...              ...               ...                     ...
# 1039605        67         1.492537                 0                   85741
# 1039606        67         1.492537                 0                   85921
# 1039607        67         1.492537                 0                   86041
# 1039608        67         1.492537                 0                   86161
# 1039609        67         1.492537                 0                   86281
#
# [1039610 rows x 19 columns]

# %%
dftest['heure'] = dftest["time"].dt.hour
dftest['jour'] = dftest["time"].dt.day
dftest['minute'] = dftest["time"].dt.minute

# %%
dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039610 entries, 0 to 1039609
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   station_id                1039610 non-null  int64
#  1   num_bikes_available       1039610 non-null  int64
#  2   num_bikes_available_mech  1035248 non-null  float64
#  3   num_bikes_available_elec  1035248 non-null  float64
#  4   num_docks_available       1039610 non-null  int64
#  5   is_installed              1039610 non-null  int64
#  6   is_returning              1039610 non-null  int64
#  7   is_renting                1039610 non-null  int64
#  8   last_reported             1039610 non-null  int64
#  9   time                      1039610 non-null  datetime64[ns]
#  10  weekday                   1039610 non-null  int64
#  11  hour                      1039610 non-null  object
#  12  name                      1039610 non-null  object
#  13  lat                       1039610 non-null  float64
#  14  lon                       1039610 non-null  float64
#  15  capacity                  1039610 non-null  int64
#  16  occupation_prct           1028885 non-null  float64
#  17  occupation_class          1039610 non-null  int64
#  18  seconds_since_midnight    1039610 non-null  int64
#  19  heure                     1039610 non-null  int64
#  20  jour                      1039610 non-null  int64
#  21  minute                    1039610 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(14), object(2)
# memory usage: 174.5+ MB

# %%
DF0 = dst.getDataset("2023_03_17")
DF1 = dst.getDataset("2023_03_18")
DF2 = dst.getDataset("2023_03_19")
DF3 = dst.getDataset("2023_03_20")
DF4 = dst.getDataset("2023_03_21")

# %%
def getDatasetStation(station_id: int) -> object:    
    return pd.concat([
        DF0[DF0["station_id"] == station_id],
        DF1[DF1["station_id"] == station_id],
        DF2[DF2["station_id"] == station_id],
        DF3[DF3["station_id"] == station_id],
        DF4[DF4["station_id"] == station_id],
    ])

def getAllStations(step: int) -> object:    
    return pd.concat([
        DF0.iloc[0::step],
        DF1.iloc[0::step],
        DF2.iloc[0::step],
        DF3.iloc[0::step],
        DF4.iloc[0::step],
    ])

# %%
def preProcessDataframe(df: object) -> object:
    dfret = df.dropna(subset = [
        "station_id", 
        "lat", 
        "lon", 
        "occupation_prct", 
        "occupation_class"
    ])
    
    dfret['jour'] = dfret["time"].dt.day
    dfret['heure'] = dfret["time"].dt.hour
    dfret['minute'] = dfret["time"].dt.minute
    
    return dfret

# %%
preProcessDataframe(getDatasetStation(100863462))
# Out:
#         station_id  num_bikes_available  num_bikes_available_mech  \
# 295431   100863462                   32                      23.0
# 295432   100863462                   30                      22.0
# 295433   100863462                   28                      23.0
# 295434   100863462                   28                      23.0
# 295435   100863462                   27                      22.0
# ...            ...                  ...                       ...
# 982699   100863462                    1                       1.0
# 982700   100863462                    1                       1.0
# 982701   100863462                    1                       1.0
# 982702   100863462                    1                       1.0
# 982703   100863462                    1                       1.0
#
#         num_bikes_available_elec  num_docks_available  is_installed  \
# 295431                       9.0                   26             1
# 295432                       8.0                   28             1
# 295433                       5.0                   30             1
# 295434                       5.0                   30             1
# 295435                       5.0                   31             1
# ...                          ...                  ...           ...
# 982699                       0.0                   58             1
# 982700                       0.0                   58             1
# 982701                       0.0                   58             1
# 982702                       0.0                   58             1
# 982703                       0.0                   58             1
#
#         is_returning  is_renting  last_reported                time  ...  \
# 295431             1           1     1679066643 2023-03-17 16:30:22  ...
# 295432             1           1     1679066643 2023-03-17 16:34:22  ...
# 295433             1           1     1679066643 2023-03-17 16:57:24  ...
# 295434             1           1     1679066643 2023-03-17 16:59:24  ...
# 295435             1           1     1679066643 2023-03-17 17:01:24  ...
# ...              ...         ...            ...                 ...  ...
# 982699             1           1     1679438002 2023-03-21 23:50:46  ...
# 982700             1           1     1679438002 2023-03-21 23:52:46  ...
# 982701             1           1     1679438002 2023-03-21 23:54:46  ...
# 982702             1           1     1679438002 2023-03-21 23:56:46  ...
# 982703             1           1     1679438002 2023-03-21 23:58:46  ...
#
#                  name        lat      lon  capacity  occupation_prct  \
# 295431  Musée d'Orsay  48.859726  2.32586        65        49.230769
# 295432  Musée d'Orsay  48.859726  2.32586        65        46.153846
# 295433  Musée d'Orsay  48.859726  2.32586        65        43.076923
# 295434  Musée d'Orsay  48.859726  2.32586        65        43.076923
# 295435  Musée d'Orsay  48.859726  2.32586        65        41.538462
# ...               ...        ...      ...       ...              ...
# 982699  Musée d'Orsay  48.859726  2.32586        65         1.538462
# 982700  Musée d'Orsay  48.859726  2.32586        65         1.538462
# 982701  Musée d'Orsay  48.859726  2.32586        65         1.538462
# 982702  Musée d'Orsay  48.859726  2.32586        65         1.538462
# 982703  Musée d'Orsay  48.859726  2.32586        65         1.538462
#
#         occupation_class  seconds_since_midnight  jour  heure  minute
# 295431                 2                 59422.0    17     16      30
# 295432                 2                 59662.0    17     16      34
# 295433                 2                 61044.0    17     16      57
# 295434                 2                 61164.0    17     16      59
# 295435                 2                 61284.0    17     17       1
# ...                  ...                     ...   ...    ...     ...
# 982699                 0                     NaN    21     23      50
# 982700                 0                     NaN    21     23      52
# 982701                 0                     NaN    21     23      54
# 982702                 0                     NaN    21     23      56
# 982703                 0                     NaN    21     23      58
#
# [3073 rows x 22 columns]

# %%
def testClassifier(df: object) -> None:

    # feat=['station_id', 'capacity', 'seconds_since_midnight']
    feat = ["station_id", "lon", "lat", "jour", "heure", "minute"]
    target = ["occupation_class"]

    x = df[feat]
    y = df[target]

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

    clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
    clf.fit(x_train, y_train.values.ravel())

    y_pred = clf.predict(x_test)
    accuracy_score(y_test, y_pred)

    print(feat)
    print(clf.feature_importances_)

    cm = confusion_matrix(y_test, y_pred)

    sns.heatmap(cm, annot=True, cmap="Blues", fmt="g")
    plt.xlabel('Prédictions')
    plt.ylabel('Valeurs réelles')
    plt.show()
    print(classification_report(y_test,y_pred))

# %%
testClassifier(preProcessDataframe(getDatasetStation(128932790)))
# Out:
# ['station_id', 'lon', 'lat', 'jour', 'heure', 'minute']
# [0.         0.         0.         0.16656207 0.80619918 0.02723874]
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       308
#            1       0.77      0.46      0.58       163
#            2       0.81      0.89      0.85        97
#            3       0.77      0.65      0.70        31
#            4       0.79      0.94      0.86        16
#
#     accuracy                           0.79       615
#    macro avg       0.79      0.77      0.77       615
# weighted avg       0.79      0.79      0.77       615

# %%
testClassifier(preProcessDataframe(getAllStations(10)))
# Out:
# /tmp/ipykernel_18799/335657735.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfret['jour'] = dfret["time"].dt.day
# /tmp/ipykernel_18799/335657735.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfret['heure'] = dfret["time"].dt.hour
# /tmp/ipykernel_18799/335657735.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfret['minute'] = dfret["time"].dt.minute
# ['station_id', 'lon', 'lat', 'jour', 'heure', 'minute']
# [0.05926047 0.1818574  0.70437322 0.00941107 0.04509783 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.74      0.07      0.12     10093
#            1       0.45      0.54      0.49     29614
#            2       0.47      0.69      0.56     34777
#            3       0.48      0.05      0.09     11438
#            4       0.86      0.01      0.02      2519
#
#     accuracy                           0.47     88441
#    macro avg       0.60      0.27      0.26     88441
# weighted avg       0.51      0.47      0.41     88441

# %%
for sample in random.sample(list(DF0["station_id"].unique()), 1):
    print(DF0[DF0["station_id"] == sample]["name"].unique())
    testClassifier(preProcessDataframe(getDatasetStation(sample)))
# Out:
# ['Jean Calvin - Tournefort']
# ['station_id', 'lon', 'lat', 'jour', 'heure', 'minute']
# [0.         0.         0.         0.70068105 0.27283141 0.02648755]
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55       150
#            1       0.68      0.80      0.73       283
#            2       0.54      0.46      0.50       139
#            3       0.67      0.56      0.61        18
#            4       0.80      0.80      0.80        25
#
#     accuracy                           0.64       615
#    macro avg       0.66      0.62      0.64       615
# weighted avg       0.64      0.64      0.64       615

# %%
def testRegressor(df: object) -> None:

    # feat=['station_id', 'capacity', 'seconds_since_midnight']
    
    """
        Utiliser l'horizon d'une journée pour plus tard
        
        horizon = 720

        feat = ["station_id", "lon", "lat", "jour", "heure", "minute"]
        target = ["occupation_prct"]

        x = test[feat]
        y = test[target]
        horizon = 720
        x_train, x_test = x.iloc[:-horizon,:], x.iloc[-horizon:,:]
        y_train, y_test = y.iloc[:-horizon], y.iloc[-horizon:]
    """
    
    dfbis = df.set_index("time")
    feat = ["station_id", "lon", "lat", "jour", "heure", "minute"]
    target = ["occupation_prct"]

    x = dfbis[feat]
    y = dfbis[target]
    
    # Méthode classique
    #x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
    
    horizon = 720
    x_train, x_test = x.iloc[:-horizon,:], x.iloc[-horizon:,:]
    y_train, y_test = y.iloc[:-horizon], y.iloc[-horizon:]

    x_train = x_train.sort_index()
    y_train = y_train.sort_index()
    x_test = x_test.sort_index()
    y_test = y_test.sort_index()

    clf = GradientBoostingRegressor(random_state=0)
    clf.fit(x_train, y_train.values.ravel())

    y_pred = clf.predict(x_test)
    
    mae = np.round(mean_absolute_error(y_test, y_pred), 3)
    
    #plot reality vs prediction for the last week of the dataset
    fig = plt.figure(figsize=(16,6))
    plt.title(f'Real vs Prediction - MAE {mae}', fontsize=20)
    plt.plot(y_test, color='red')
    plt.plot(pd.Series(y_pred, index = y_test.index), color='green')
    plt.xlabel('Hour', fontsize = 16)
    plt.ylabel('Occupation Prct', fontsize = 16)
    plt.legend(labels=['Real', 'Prediction'], fontsize = 16)
    plt.grid()
    plt.show()
    
    #create a dataframe with the variable importances of the model
    df_importances = pd.DataFrame({
        'feature': clf.feature_names_in_,
        'importance': clf.feature_importances_
    }).sort_values(by='importance', ascending=False)
    
    #plot variable importances of the model
    plt.title('Variable Importances', fontsize=16)
    sns.barplot(x = df_importances.importance, y = df_importances.feature, orient='h')
    plt.show()

# %%
for sample in random.sample(list(DF0["station_id"].unique()), 1):
    print(DF0[DF0["station_id"] == sample]["name"].unique())
    testRegressor(preProcessDataframe(getDatasetStation(sample)))
# Out:
# ["Bourg l'Abbé - Saint-Martin"]

# %%
test = preProcessDataframe(getDatasetStation(99886640))

samedi = test[test["jour"] == 18]
samedi["time"] = samedi['time'].apply(lambda dt: dt.replace(day = 21))
samedi = samedi.set_index('time').sort_index()
dimanche = test[test["jour"] == 19]
dimanche["time"] = dimanche['time'].apply(lambda dt: dt.replace(day = 21))
dimanche = dimanche.set_index('time').sort_index()
lundi = test[test["jour"] == 20]
lundi["time"] = lundi['time'].apply(lambda dt: dt.replace(day = 21))
lundi = lundi.set_index('time').sort_index()
mardi = test[test["jour"] == 21].set_index('time').sort_index()

fig = plt.figure(figsize=(16,6))
plt.title(f'Lundi vs Mardi', fontsize=20)
plt.plot(samedi["occupation_prct"], color='orange')
plt.plot(dimanche["occupation_prct"], color='blue')
plt.plot(lundi["occupation_prct"], color='green')
plt.plot(mardi["occupation_prct"], color='red')
plt.xlabel('Hour', fontsize = 16)
plt.ylabel('Occupation Prct', fontsize = 16)
plt.legend(labels=['Samedi', 'Dimanche','Lundi', 'Mardi'], fontsize = 16)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_18799/2049642192.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   samedi["time"] = samedi['time'].apply(lambda dt: dt.replace(day = 21))
# /tmp/ipykernel_18799/2049642192.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dimanche["time"] = dimanche['time'].apply(lambda dt: dt.replace(day = 21))
# /tmp/ipykernel_18799/2049642192.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lundi["time"] = lundi['time'].apply(lambda dt: dt.replace(day = 21))

# %%
dfbis = preProcessDataframe(getDatasetStation(128932790)).set_index("time")
feat = ["station_id", "lon", "lat", "jour", "heure", "minute"]
target = ["occupation_prct"]

x = dfbis[feat]
y = dfbis[target]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

x_train = x_train.sort_index()
y_train = x_train.sort_index()
x_test = x_train.sort_index()
y_test = x_train.sort_index()

# %%
y_test.sort_index()
# Out:
#                      station_id      lon        lat  jour  heure  minute
# time
# 2023-03-17 16:30:22   128932790  2.29779  48.873409    17     16      30
# 2023-03-17 16:34:22   128932790  2.29779  48.873409    17     16      34
# 2023-03-17 16:57:24   128932790  2.29779  48.873409    17     16      57
# 2023-03-17 16:59:24   128932790  2.29779  48.873409    17     16      59
# 2023-03-17 17:01:24   128932790  2.29779  48.873409    17     17       1
# ...                         ...      ...        ...   ...    ...     ...
# 2023-03-21 23:48:46   128932790  2.29779  48.873409    21     23      48
# 2023-03-21 23:52:46   128932790  2.29779  48.873409    21     23      52
# 2023-03-21 23:54:46   128932790  2.29779  48.873409    21     23      54
# 2023-03-21 23:56:46   128932790  2.29779  48.873409    21     23      56
# 2023-03-21 23:58:46   128932790  2.29779  48.873409    21     23      58
#
# [2458 rows x 6 columns]

# %%
preProcessDataframe(getDatasetStation(99886640))
# Out:
#         station_id  num_bikes_available  num_bikes_available_mech  \
# 249210    99886640                   21                      19.0
# 249211    99886640                   20                      18.0
# 249212    99886640                   20                      18.0
# 249213    99886640                   19                      17.0
# 249214    99886640                   19                      18.0
# ...            ...                  ...                       ...
# 829063    99886640                    4                       3.0
# 829064    99886640                    4                       3.0
# 829065    99886640                    4                       3.0
# 829066    99886640                    2                       1.0
# 829067    99886640                    2                       1.0
#
#         num_bikes_available_elec  num_docks_available  is_installed  \
# 249210                       2.0                    2             1
# 249211                       2.0                    3             1
# 249212                       2.0                    3             1
# 249213                       2.0                    4             1
# 249214                       1.0                    4             1
# ...                          ...                  ...           ...
# 829063                       1.0                   19             1
# 829064                       1.0                   19             1
# 829065                       1.0                   19             1
# 829066                       1.0                   21             1
# 829067                       1.0                   21             1
#
#         is_returning  is_renting  last_reported                time  ...  \
# 249210             1           1     1679066901 2023-03-17 16:30:22  ...
# 249211             1           1     1679066901 2023-03-17 16:34:22  ...
# 249212             1           1     1679066901 2023-03-17 16:57:24  ...
# 249213             1           1     1679066901 2023-03-17 16:59:24  ...
# 249214             1           1     1679066901 2023-03-17 17:01:24  ...
# ...              ...         ...            ...                 ...  ...
# 829063             1           1     1679438034 2023-03-21 23:50:46  ...
# 829064             1           1     1679438034 2023-03-21 23:52:46  ...
# 829065             1           1     1679438034 2023-03-21 23:54:46  ...
# 829066             1           1     1679438034 2023-03-21 23:56:46  ...
# 829067             1           1     1679438034 2023-03-21 23:58:46  ...
#
#                        name        lat       lon  capacity  occupation_prct  \
# 249210  Place des Victoires  48.866035  2.342033        24        87.500000
# 249211  Place des Victoires  48.866035  2.342033        24        83.333333
# 249212  Place des Victoires  48.866035  2.342033        24        83.333333
# 249213  Place des Victoires  48.866035  2.342033        24        79.166667
# 249214  Place des Victoires  48.866035  2.342033        24        79.166667
# ...                     ...        ...       ...       ...              ...
# 829063  Place des Victoires  48.866035  2.342033        24        16.666667
# 829064  Place des Victoires  48.866035  2.342033        24        16.666667
# 829065  Place des Victoires  48.866035  2.342033        24        16.666667
# 829066  Place des Victoires  48.866035  2.342033        24         8.333333
# 829067  Place des Victoires  48.866035  2.342033        24         8.333333
#
#         occupation_class  seconds_since_midnight  jour  heure  minute
# 249210                 3                 59422.0    17     16      30
# 249211                 3                 59662.0    17     16      34
# 249212                 3                 61044.0    17     16      57
# 249213                 3                 61164.0    17     16      59
# 249214                 3                 61284.0    17     17       1
# ...                  ...                     ...   ...    ...     ...
# 829063                 1                     NaN    21     23      50
# 829064                 1                     NaN    21     23      52
# 829065                 1                     NaN    21     23      54
# 829066                 1                     NaN    21     23      56
# 829067                 1                     NaN    21     23      58
#
# [3073 rows x 22 columns]
